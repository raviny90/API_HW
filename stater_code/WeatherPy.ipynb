# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 606

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# a.
# Processing Record 22  of Set 4 | lasa.
# Processing Record 23  of Set 4 | cabo san lucas.
# Processing Record 24  of Set 4 | kodiak.
# Processing Record 25  of Set 4 | pilar.
# Processing Record 26  of Set 4 | moree.
# Processing Record 27  of Set 4 | onguday.
# Processing Record 28  of Set 4 | lushunkou.
# City not found...skipping lushunkou.
# Processing Record 29  of Set 4 | obluche.
# City not found...skipping obluche.
# Processing Record 30  of Set 4 | paracatu.
# Processing Record 31  of Set 4 | cuamba.
# Processing Record 32  of Set 4 | karaul.
# City not found...skipping karaul.
# Processing Record 33  of Set 4 | ponta do sol.
# Processing Record 34  of Set 4 | komsomolskiy.
# Processing Record 35  of Set 4 | novoagansk.
# Processing Record 36  of Set 4 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 37  of Set 4 | thompson.
# Processing Record 38  of Set 4 | vardo.
# Processing Record 39  of Set 4 | jamestown.
# Processing Record 40  of Set 4 | harper.
# Processing Record 41  of Set 4 | arlit.
# Processing Record 42  of Set 4 | maningrida.
# Processing Record 43  of Set 4 | namibe.
# Processing Record 44  of Set 4 | vila franca do campo.
# Processing Record 45  of Set 4 | kahului.
# Processing Record 46  of Set 4 | yellowknife.
# Processing Record 47  of Set 4 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 48  of Set 4 | lagoa.
# Processing Record 49  of Set 4 | gold coast.
# Processing Record 0  of Set 5 | havre-saint-pierre.
# Processing Record 1  of Set 5 | surman.
# Processing Record 2  of Set 5 | gat.
# Processing Record 3  of Set 5 | salalah.
# Processing Record 4  of Set 5 | beloha.
# Processing Record 5  of Set 5 | cidreira.
# Processing Record 6  of Set 5 | touros.
# Processing Record 7  of Set 5 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 8  of Set 5 | atka.
# City not found...skipping atka.
# Processing Record 9  of Set 5 | mtsamboro.
# Processing Record 10  of Set 5 | gisenyi.
# Processing Record 11  of Set 5 | bethel.
# Processing Record 12  of Set 5 | mumbwa.
# Processing Record 13  of Set 5 | manuk mangkaw.
# Processing Record 14  of Set 5 | lata.
# Processing Record 15  of Set 5 | les cayes.
# Processing Record 16  of Set 5 | kaitangata.
# Processing Record 17  of Set 5 | aswan.
# Processing Record 18  of Set 5 | zhigansk.
# Processing Record 19  of Set 5 | tuatapere.
# Processing Record 20  of Set 5 | lahaina.
# Processing Record 21  of Set 5 | forquilhinha.
# Processing Record 22  of Set 5 | marawi.
# Processing Record 23  of Set 5 | ponta delgada.
# Processing Record 24  of Set 5 | salta.
# Processing Record 25  of Set 5 | severo-kurilsk.
# Processing Record 26  of Set 5 | forestville.
# Processing Record 27  of Set 5 | bahia honda.
# Processing Record 28  of Set 5 | beyneu.
# Processing Record 29  of Set 5 | loikaw.
# Processing Record 30  of Set 5 | mahebourg.
# Processing Record 31  of Set 5 | urengoy.
# Processing Record 32  of Set 5 | padre bernardo.
# Processing Record 33  of Set 5 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 34  of Set 5 | nome.
# Processing Record 35  of Set 5 | avarua.
# Processing Record 36  of Set 5 | kapoeta.
# Processing Record 37  of Set 5 | warqla.
# City not found...skipping warqla.
# Processing Record 38  of Set 5 | kropotkin.
# Processing Record 39  of Set 5 | lagos.
# Processing Record 40  of Set 5 | lucapa.
# Processing Record 41  of Set 5 | farroupilha.
# Processing Record 42  of Set 5 | jacksonville.
# Processing Record 43  of Set 5 | bintulu.
# Processing Record 44  of Set 5 | kruisfontein.
# Processing Record 45  of Set 5 | batagay-alyta.
# Processing Record 46  of Set 5 | bulgan.
# Processing Record 47  of Set 5 | sirjan.
# Processing Record 48  of Set 5 | halifax.
# Processing Record 49  of Set 5 | northam.
# Processing Record 0  of Set 6 | gondanglegi.
# Processing Record 1  of Set 6 | iskateley.
# Processing Record 2  of Set 6 | tabiauea.
# City not found...skipping tabiauea.
# Processing Record 3  of Set 6 | upernavik.
# Processing Record 4  of Set 6 | sishui.
# Processing Record 5  of Set 6 | bantry.
# Processing Record 6  of Set 6 | samusu.
# City not found...skipping samusu.
# Processing Record 7  of Set 6 | alberton.
# Processing Record 8  of Set 6 | havoysund.
# Processing Record 9  of Set 6 | ilulissat.
# Processing Record 10  of Set 6 | bairiki.
# Processing Record 11  of Set 6 | padang.
# Processing Record 12  of Set 6 | solovetskiy.
# City not found...skipping solovetskiy.
# Processing Record 13  of Set 6 | iqaluit.
# Processing Record 14  of Set 6 | narasannapeta.
# Processing Record 15  of Set 6 | takoradi.
# Processing Record 16  of Set 6 | pitimbu.
# Processing Record 17  of Set 6 | zorritos.
# Processing Record 18  of Set 6 | dwarka.
# Processing Record 19  of Set 6 | laguna.
# Processing Record 20  of Set 6 | danville.
# Processing Record 21  of Set 6 | satitoa.
# City not found...skipping satitoa.
# Processing Record 22  of Set 6 | izoplit.
# Processing Record 23  of Set 6 | ixtapa.
# Processing Record 24  of Set 6 | tzucacab.
# Processing Record 25  of Set 6 | tome.
# Processing Record 26  of Set 6 | shelburne.
# Processing Record 27  of Set 6 | vallenar.
# Processing Record 28  of Set 6 | guangzhou.
# Processing Record 29  of Set 6 | kroya.
# Processing Record 30  of Set 6 | antofagasta.
# Processing Record 31  of Set 6 | longyearbyen.
# Processing Record 32  of Set 6 | miri.
# Processing Record 33  of Set 6 | constitucion.
# Processing Record 34  of Set 6 | halmstad.
# Processing Record 35  of Set 6 | college.
# Processing Record 36  of Set 6 | mitsuke.
# Processing Record 37  of Set 6 | tallahassee.
# Processing Record 38  of Set 6 | qarqin.
# Processing Record 39  of Set 6 | cherskiy.
# Processing Record 40  of Set 6 | amderma.
# City not found...skipping amderma.
# Processing Record 41  of Set 6 | geraldton.
# Processing Record 42  of Set 6 | hunza.
# City not found...skipping hunza.
# Processing Record 43  of Set 6 | novobirilyussy.
# Processing Record 44  of Set 6 | mirabad.
# Processing Record 45  of Set 6 | baykit.
# Processing Record 46  of Set 6 | cayenne.
# Processing Record 47  of Set 6 | toliary.
# City not found...skipping toliary.
# Processing Record 48  of Set 6 | kidal.
# Processing Record 49  of Set 6 | acarau.
# Processing Record 0  of Set 7 | boddam.
# Processing Record 1  of Set 7 | homer.
# Processing Record 2  of Set 7 | myre.
# Processing Record 3  of Set 7 | tombouctou.
# Processing Record 4  of Set 7 | ofunato.
# Processing Record 5  of Set 7 | kununurra.
# Processing Record 6  of Set 7 | blois.
# Processing Record 7  of Set 7 | port hardy.
# Processing Record 8  of Set 7 | sur.
# Processing Record 9  of Set 7 | balkanabat.
# Processing Record 10  of Set 7 | lorengau.
# Processing Record 11  of Set 7 | piacabucu.
# Processing Record 12  of Set 7 | tilichiki.
# Processing Record 13  of Set 7 | husavik.
# Processing Record 14  of Set 7 | gravdal.
# Processing Record 15  of Set 7 | victoria.
# Processing Record 16  of Set 7 | shitanjing.
# Processing Record 17  of Set 7 | conselheiro lafaiete.
# Processing Record 18  of Set 7 | aparecida do taboado.
# Processing Record 19  of Set 7 | avera.
# Processing Record 20  of Set 7 | manjacaze.
# Processing Record 21  of Set 7 | inhambane.
# Processing Record 22  of Set 7 | thunder bay.
# Processing Record 23  of Set 7 | pozo colorado.
# Processing Record 24  of Set 7 | saint-louis.
# Processing Record 25  of Set 7 | baracoa.
# Processing Record 26  of Set 7 | yar-sale.
# Processing Record 27  of Set 7 | cockburn town.
# Processing Record 28  of Set 7 | vestmannaeyjar.
# Processing Record 29  of Set 7 | alzey.
# Processing Record 30  of Set 7 | aklavik.
# Processing Record 31  of Set 7 | senno.
# Processing Record 32  of Set 7 | penon blanco.
# Processing Record 33  of Set 7 | hasaki.
# Processing Record 34  of Set 7 | destin.
# Processing Record 35  of Set 7 | arawa.
# Processing Record 36  of Set 7 | caravelas.
# Processing Record 37  of Set 7 | hoi an.
# Processing Record 38  of Set 7 | mwene-ditu.
# Processing Record 39  of Set 7 | san andres.
# Processing Record 40  of Set 7 | fenoarivo.
# Processing Record 41  of Set 7 | mildura.
# Processing Record 42  of Set 7 | tiksi.
# Processing Record 43  of Set 7 | weston.
# Processing Record 44  of Set 7 | pocoes.
# Processing Record 45  of Set 7 | bushehr.
# Processing Record 46  of Set 7 | sobolevo.
# Processing Record 47  of Set 7 | umm durman.
# City not found...skipping umm durman.
# Processing Record 48  of Set 7 | marcona.
# City not found...skipping marcona.
# Processing Record 49  of Set 7 | tura.
# Processing Record 0  of Set 8 | chumikan.
# Processing Record 1  of Set 8 | port macquarie.
# Processing Record 2  of Set 8 | saldanha.
# Processing Record 3  of Set 8 | alta floresta.
# Processing Record 4  of Set 8 | kingsland.
# Processing Record 5  of Set 8 | bilibino.
# Processing Record 6  of Set 8 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 7  of Set 8 | jacksonville beach.
# Processing Record 8  of Set 8 | xifeng.
# Processing Record 9  of Set 8 | holalkere.
# Processing Record 10  of Set 8 | saint-joseph.
# Processing Record 11  of Set 8 | belaya gora.
# Processing Record 12  of Set 8 | hofn.
# Processing Record 13  of Set 8 | san patricio.
# Processing Record 14  of Set 8 | soyo.
# Processing Record 15  of Set 8 | valparaiso.
# Processing Record 16  of Set 8 | rio verde de mato grosso.
# Processing Record 17  of Set 8 | mitsamiouli.
# Processing Record 18  of Set 8 | finschhafen.
# Processing Record 19  of Set 8 | san quintin.
# Processing Record 20  of Set 8 | vila do maio.
# Processing Record 21  of Set 8 | beringovskiy.
# Processing Record 22  of Set 8 | eureka.
# Processing Record 23  of Set 8 | cotonou.
# Processing Record 24  of Set 8 | fortuna.
# Processing Record 25  of Set 8 | cedar city.
# Processing Record 26  of Set 8 | hervey bay.
# Processing Record 27  of Set 8 | jalu.
# Processing Record 28  of Set 8 | okha.
# Processing Record 29  of Set 8 | tuy hoa.
# Processing Record 30  of Set 8 | pecos.
# Processing Record 31  of Set 8 | oranjemund.
# Processing Record 32  of Set 8 | phayuha khiri.
# Processing Record 33  of Set 8 | shimoda.
# Processing Record 34  of Set 8 | boa vista.
# Processing Record 35  of Set 8 | srandakan.
# Processing Record 36  of Set 8 | oistins.
# Processing Record 37  of Set 8 | khandyga.
# Processing Record 38  of Set 8 | abha.
# Processing Record 39  of Set 8 | bereda.
# Processing Record 40  of Set 8 | odesa.
# Processing Record 41  of Set 8 | sibolga.
# Processing Record 42  of Set 8 | pahrump.
# Processing Record 43  of Set 8 | verkhnevilyuysk.
# Processing Record 44  of Set 8 | alice springs.
# Processing Record 45  of Set 8 | bhimunipatnam.
# Processing Record 46  of Set 8 | grand gaube.
# Processing Record 47  of Set 8 | moroni.
# Processing Record 48  of Set 8 | wonthaggi.
# Processing Record 49  of Set 8 | talcahuano.
# Processing Record 0  of Set 9 | north bend.
# Processing Record 1  of Set 9 | tibiao.
# Processing Record 2  of Set 9 | ayolas.
# Processing Record 3  of Set 9 | tricase.
# Processing Record 4  of Set 9 | el dorado.
# Processing Record 5  of Set 9 | tubinskiy.
# Processing Record 6  of Set 9 | naryan-mar.
# Processing Record 7  of Set 9 | mount isa.
# Processing Record 8  of Set 9 | gresham.
# Processing Record 9  of Set 9 | nikolskoye.
# Processing Record 10  of Set 9 | cangzhou.
# Processing Record 11  of Set 9 | talara.
# Processing Record 12  of Set 9 | amahai.
# Processing Record 13  of Set 9 | vao.
# Processing Record 14  of Set 9 | lazaro cardenas.
# Processing Record 15  of Set 9 | ankara.
# Processing Record 16  of Set 9 | darlawn.
# Processing Record 17  of Set 9 | mezhdurechensk.
# Processing Record 18  of Set 9 | teahupoo.
# Processing Record 19  of Set 9 | hambantota.
# Processing Record 20  of Set 9 | kihei.
# Processing Record 21  of Set 9 | kattivakkam.
# Processing Record 22  of Set 9 | alyangula.
# Processing Record 23  of Set 9 | korba.
# Processing Record 24  of Set 9 | faanui.
# Processing Record 25  of Set 9 | ewa beach.
# Processing Record 26  of Set 9 | pailon.
# Processing Record 27  of Set 9 | marzuq.
# Processing Record 28  of Set 9 | matara.
# Processing Record 29  of Set 9 | valle hermoso.
# Processing Record 30  of Set 9 | kashi.
# Processing Record 31  of Set 9 | cam ranh.
# Processing Record 32  of Set 9 | bud.
# Processing Record 33  of Set 9 | seoul.
# Processing Record 34  of Set 9 | zaranj.
# Processing Record 35  of Set 9 | maracaju.
# Processing Record 36  of Set 9 | basoko.
# Processing Record 37  of Set 9 | sagua la grande.
# Processing Record 38  of Set 9 | biak.
# Processing Record 39  of Set 9 | sarakhs.
# Processing Record 40  of Set 9 | mareeba.
# Processing Record 41  of Set 9 | labytnangi.
# Processing Record 42  of Set 9 | nizwa.
# Processing Record 43  of Set 9 | imperatriz.
# Processing Record 44  of Set 9 | vila.
# Processing Record 45  of Set 9 | egvekinot.
# Processing Record 46  of Set 9 | palpa.
# Processing Record 47  of Set 9 | shakawe.
# Processing Record 48  of Set 9 | banska bystrica.
# Processing Record 49  of Set 9 | alekseyevsk.
# Processing Record 0  of Set 10 | benjamin aceval.
# Processing Record 1  of Set 10 | ayios matthaios.
# City not found...skipping ayios matthaios.
# Processing Record 2  of Set 10 | pilao arcado.
# City not found...skipping pilao arcado.
# Processing Record 3  of Set 10 | kyshtovka.
# Processing Record 4  of Set 10 | viedma.
# Processing Record 5  of Set 10 | reyes.
# Processing Record 6  of Set 10 | gambela.
# Processing Record 7  of Set 10 | rincon.
# Processing Record 8  of Set 10 | avigliana.
# Processing Record 9  of Set 10 | chicama.
# Processing Record 10  of Set 10 | ulaanbaatar.
# Processing Record 11  of Set 10 | yulara.
# Processing Record 12  of Set 10 | lawrenceburg.
# Processing Record 13  of Set 10 | skagastrond.
# City not found...skipping skagastrond.
# Processing Record 14  of Set 10 | clyde river.
# Processing Record 15  of Set 10 | coihaique.
# Processing Record 16  of Set 10 | ahipara.
# Processing Record 17  of Set 10 | hinche.
# Processing Record 18  of Set 10 | isangel.
# Processing Record 19  of Set 10 | sao jose da coroa grande.
# Processing Record 20  of Set 10 | tual.
# Processing Record 21  of Set 10 | nuevo ideal.
# Processing Record 22  of Set 10 | bonthe.
# Processing Record 23  of Set 10 | bulancak.
# Processing Record 24  of Set 10 | port augusta.
# Processing Record 25  of Set 10 | khani.
# Processing Record 26  of Set 10 | rocha.
# Processing Record 27  of Set 10 | cairns.
# Processing Record 28  of Set 10 | jackson.
# Processing Record 29  of Set 10 | el alto.
# Processing Record 30  of Set 10 | lethem.
# Processing Record 31  of Set 10 | fort wellington.
# Processing Record 32  of Set 10 | qaqortoq.
# Processing Record 33  of Set 10 | derzhavinsk.
# Processing Record 34  of Set 10 | upleta.
# Processing Record 35  of Set 10 | araouane.
# Processing Record 36  of Set 10 | brae.
# Processing Record 37  of Set 10 | korla.
# Processing Record 38  of Set 10 | ust-omchug.
# Processing Record 39  of Set 10 | tabou.
# Processing Record 40  of Set 10 | san jose.
# Processing Record 41  of Set 10 | bandarbeyla.
# Processing Record 42  of Set 10 | boca do acre.
# Processing Record 43  of Set 10 | barentu.
# Processing Record 44  of Set 10 | hillsborough.
# Processing Record 45  of Set 10 | belmonte.
# Processing Record 46  of Set 10 | dunedin.
# Processing Record 47  of Set 10 | malibu.
# Processing Record 48  of Set 10 | fernie.
# Processing Record 49  of Set 10 | sananduva.
# Processing Record 0  of Set 11 | durango.
# Processing Record 1  of Set 11 | karaton.
# Processing Record 2  of Set 11 | alamosa.
# Processing Record 3  of Set 11 | marsa matruh.
# Processing Record 4  of Set 11 | gairo.
# Processing Record 5  of Set 11 | volot.
# Processing Record 6  of Set 11 | carutapera.
# Processing Record 7  of Set 11 | saint-gilles.
# Processing Record 8  of Set 11 | salto.
# Processing Record 9  of Set 11 | constantine.
# Processing Record 10  of Set 11 | pochutla.
# Processing Record 11  of Set 11 | ylivieska.
# Processing Record 12  of Set 11 | porto de moz.
# Processing Record 13  of Set 11 | bat khela.
# Processing Record 14  of Set 11 | pachino.
# Processing Record 15  of Set 11 | nampula.
# Processing Record 16  of Set 11 | adrar.
# Processing Record 17  of Set 11 | shache.
# Processing Record 18  of Set 11 | bowmore.
# Processing Record 19  of Set 11 | tungor.
# Processing Record 20  of Set 11 | birao.
# Processing Record 21  of Set 11 | leh.
# Processing Record 22  of Set 11 | dorchester.
# Processing Record 23  of Set 11 | zhangye.
# Processing Record 24  of Set 11 | manokwari.
# Processing Record 25  of Set 11 | huarmey.
# Processing Record 26  of Set 11 | omboue.
# Processing Record 27  of Set 11 | chapais.
# Processing Record 28  of Set 11 | yuzhno-yeniseyskiy.
# City not found...skipping yuzhno-yeniseyskiy.
# Processing Record 29  of Set 11 | kumluca.
# Processing Record 30  of Set 11 | porto santo.
# Processing Record 31  of Set 11 | cap-aux-meules.
# Processing Record 32  of Set 11 | pangody.
# Processing Record 33  of Set 11 | slave lake.
# Processing Record 34  of Set 11 | batagay.
# Processing Record 35  of Set 11 | maldonado.
# Processing Record 36  of Set 11 | great yarmouth.
# Processing Record 37  of Set 11 | juneau.
# Processing Record 38  of Set 11 | rio gallegos.
# Processing Record 39  of Set 11 | yomitan.
# City not found...skipping yomitan.
# Processing Record 40  of Set 11 | lolua.
# City not found...skipping lolua.
# Processing Record 41  of Set 11 | frantiskovy lazne.
# Processing Record 42  of Set 11 | berdigestyakh.
# Processing Record 43  of Set 11 | stonehouse.
# Processing Record 44  of Set 11 | nishihara.
# Processing Record 45  of Set 11 | ulaangom.
# Processing Record 46  of Set 11 | coahuayana.
# Processing Record 47  of Set 11 | caraquet.
# Processing Record 48  of Set 11 | troitskoye.
# Processing Record 49  of Set 11 | pacific grove.
# Processing Record 0  of Set 12 | zyryanka.
# Processing Record 1  of Set 12 | unye.
# City not found...skipping unye.
# Processing Record 2  of Set 12 | brewster.
# Processing Record 3  of Set 12 | kiunga.
# Processing Record 4  of Set 12 | waynesville.
# Processing Record 5  of Set 12 | neftegorsk.
# Processing Record 6  of Set 12 | saint anthony.
# Processing Record 7  of Set 12 | namatanai.
# Processing Record 8  of Set 12 | dubai.
# Processing Record 9  of Set 12 | galt.
# Processing Record 10  of Set 12 | scarborough.
# Processing Record 11  of Set 12 | bharatpur.
# Processing Record 12  of Set 12 | semirom.
# Processing Record 13  of Set 12 | tezu.
# Processing Record 14  of Set 12 | solnechnyy.
# Processing Record 15  of Set 12 | jurado.
# Processing Record 16  of Set 12 | saint-augustin.
# Processing Record 17  of Set 12 | tessalit.
# Processing Record 18  of Set 12 | flin flon.
# Processing Record 19  of Set 12 | mumford.
# Processing Record 20  of Set 12 | puerto escondido.
# Processing Record 21  of Set 12 | merauke.
# Processing Record 22  of Set 12 | tokur.
# Processing Record 23  of Set 12 | sinnamary.
# Processing Record 24  of Set 12 | karymskoye.
# Processing Record 25  of Set 12 | sisimiut.
# Processing Record 26  of Set 12 | galle.
# Processing Record 27  of Set 12 | chalons-en-champagne.
# Processing Record 28  of Set 12 | francistown.
# Processing Record 29  of Set 12 | richards bay.
# Processing Record 30  of Set 12 | campbell river.
# Processing Record 31  of Set 12 | thai binh.
# Processing Record 32  of Set 12 | trofaiach.
# Processing Record 33  of Set 12 | stokmarknes.
# Processing Record 34  of Set 12 | halalo.
# City not found...skipping halalo.
# Processing Record 35  of Set 12 | garissa.
# Processing Record 36  of Set 12 | japura.
# Processing Record 37  of Set 12 | bani.
# Processing Record 38  of Set 12 | sistranda.
# Processing Record 39  of Set 12 | katra.
# Processing Record 40  of Set 12 | bathsheba.
# Processing Record 41  of Set 12 | kavieng.
# Processing Record 42  of Set 12 | bongandanga.
# Processing Record 43  of Set 12 | erenhot.
# Processing Record 44  of Set 12 | panjab.
# Processing Record 45  of Set 12 | flinders.
# Processing Record 46  of Set 12 | codajas.
# Processing Record 47  of Set 12 | goedereede.
# Processing Record 48  of Set 12 | luorong.
# Processing Record 49  of Set 12 | palana.
# Processing Record 0  of Set 13 | kaduy.
# Processing Record 1  of Set 13 | senanga.
# Processing Record 2  of Set 13 | cloquet.
# Processing Record 3  of Set 13 | talnakh.
# Processing Record 4  of Set 13 | terney.
# Processing Record 5  of Set 13 | talaya.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count
weather_df.count()

# %%
# Display DataFrame
weather_df.head()
# Out:
#       City Country                 Date Latitude Longitude Cloudiness (%)  \
# 0  mataura      NZ  2020-09-02 21:47:59   -46.19    168.86             50
# 1    vaini      TO  2020-09-02 21:47:59    -21.2    -175.2             75
# 2     nuuk      GL  2020-09-02 21:47:59    64.18    -51.72             11
# 3   atuona      PF  2020-09-02 21:47:59     -9.8   -139.03              7
# 4    kapaa      US  2020-09-02 21:46:46    22.08   -159.32             75
#
#   Humidity (%) Max Temp (F) Wind Speed (mph)
# 0           44       58.028             1.26
# 1           88        73.67              5.1
# 2           58        44.87              5.1
# 3           78       79.232            10.38
# 4           69       81.266              5.7

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.6x + 91.97
# The r-squared is: -0.8025357218381367
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.64x + 80.94
# The r-squared is: 0.6923475180507709
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = -0.0x + 72.14
# The r-squared is: -0.004066077235141487
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.1x + 72.5
# The r-squared is: 0.06576857493930371
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.26x + 41.74
# The r-squared is: 0.13173420162923796
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.1x + 35.9
# The r-squared is: -0.03659812352015587
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.01x + 3.15
# The r-squared is: 0.0971562366762533
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.01x + 3.33
# The r-squared is: -0.05507329646229565
# The regression does not display much of a correlation between the data sets.
